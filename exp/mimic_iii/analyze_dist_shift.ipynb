# %% [markdown]
# Goal: We want to visualize the distributional shifts between MIMIC-III and MIMIC-IV

# %%
import sys
import getpass
user_id = getpass.getuser()
sys.path.append(f"/home/{user_id}/projects/OTTEHR/")

import matplotlib.pyplot as plt
from mimic_common import *
import numpy as np
import os
import pandas as pd
from scipy import stats
# Out:
# 2025-02-18 13:38:41.023666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739914721.051818 2292790 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739914721.059892 2292790 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def custom_train_reps(source_features, target_features, n_components, pca_explain=False):
    """ 
    Customized training algorithm for generating target representations and source representations

    :param bool pca_explain: print the explained variance of each components
    
    :returns: target representations, source representations
    """
    source_pca = PCA(n_components=n_components)
    source_reps = source_pca.fit_transform(source_features)

    # Use source PCA to embed target representations (based on the assumption source and target are using the same ICD encoding system)
    target_reps = source_pca.fit_transform(target_features)

    if pca_explain:
        source_exp_var = source_pca.explained_variance_ratio_
        source_cum_sum_var = np.cumsum(source_exp_var)
        target_exp_var = source_pca.explained_variance_ratio_
        target_cum_sum_var = np.cumsum(target_exp_var)
        print("Cummulative variance explained by the source PCA is:", source_cum_sum_var[-1])
        print("Cummulative variance explained by the target PCA is:", target_cum_sum_var[-1])

    return source_reps, target_reps

# %%
def plot_pair(full_df, group_name, type, source, target, source_count, target_count, input_name, output_name, ax, n_components):
    """ 
    Plot pairwise embedding distributions between source (with source_count) and target (with target_count) on axis ax 
    """
    
    selected_df = select_samples(full_df, group_name, type, source, target, source_count=source_count, target_count=target_count)


    source_features, _, target_features, _ = gen_code_feature_label(selected_df, group_name, type, source, target, input_name, output_name)

    source_reps, target_reps = custom_train_reps(source_features, target_features, n_components)
    ax.scatter(source_reps[:, 0], source_reps[:, 1], label=source, s=1)
    ax.scatter(target_reps[:, 0], target_reps[:, 1], label=target, s=1)
    ax.legend(prop={'size': 6})

# %%
# Set parameters 
output_dir = mimic_output_dir
n_components = 50
source_count = 500
target_count = 500
type = 'cat'
input_name = 'ICD codes'
output_name = 'duration'
full_df = pd.read_csv(os.path.join(mimic_data_dir, "admission_patient_diagnosis_ICD.csv"), index_col=None, header=0, converters={'ICD codes': literal_eval})

group_name = 'insurance'
groups = ['Self_Pay', 'Private',  'Government', 'Medicare', 'Medicaid']

# group_name = 'marital_status'
# groups = ['MARRIED', 'SINGLE', 'WIDOWED', 'DIVORCED', 'SEPARATED']

# Plot pairwise plots 
fig, axs = plt.subplots(len(groups), len(groups))
fig.set_figwidth(10)
fig.set_figheight(10)

for i, group_1 in enumerate(groups):
    for j, group_2 in enumerate(groups):
        if j == 0:
            axs[i, j].set_ylabel(f'Source: {group_1}', fontsize=10)
        if i == 0:
            axs[i, j].set_title(f'Target: {group_2}', fontsize=10)
        if group_1 == group_2:
            axs[i, j].axis('off')
            continue
        plot_pair(full_df, group_name, type, group_1, group_2, \
                  source_count, target_count, input_name, output_name, axs[i,j], n_components)

fig.suptitle(f"Insurance - Feature embedding using PCA", fontsize=15)
plt.tight_layout()
# plt.savefig(os.path.join(output_dir, f"{group_name}_distn_shift.pdf"))
# Out:
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1799
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1819
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1847
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1882
# number of target indices is: 609 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1923
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1844
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1765
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1864
# number of target indices is: 609 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1828
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1800
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1867
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1962
# number of target indices is: 609 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1857
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1789
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1800
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1915
# number of target indices is: 609 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 1891
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 1840
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 1919
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 1937

# %% [markdown]
# Conduct Mann-Whitney U test to assess the distributional shifts between the embeddings in terms of medians

# %%
for i, source in enumerate(groups):
    for j, target in enumerate(groups):
        if i == j:
            continue 
        print("Source is:", source, "Target is:", target)
        selected_df = select_samples(full_df, group_name, type, source, target, source_count=source_count, target_count=target_count)

        source_features, _, target_features, _ = gen_code_feature_label(selected_df, group_name, type, source, target, input_name, output_name)

        source_reps, target_reps = custom_train_reps(source_features, target_features, n_components)

        # Results storage
        results_mann_whitney = []

        # Perform the tests for each dimension
        test_dim_num = 2 # only test the first two dimension
        for k in range(2):
            # Mann-Whitney U test for the i-th dimension
            u_stat, u_p_value = stats.mannwhitneyu(source_reps[:, k], target_reps[:, k], alternative='two-sided')
            results_mann_whitney.append((u_stat, u_p_value))
            

        # Output results
        for _, mw_res in enumerate (results_mann_whitney):
            print(f"  Mann-Whitney U test stats: {mw_res[0]}, p-value: {mw_res[1]:.2e}")
            if mw_res[1] < 0.05:
                print("  Significant difference in medians.")
            else:
                print("  No significant difference in medians.")
# Out:
# Source is: Self_Pay Target is: Private 0 1
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1780
#   Mann-Whitney U test stats: 135557.0, p-value: 2.08e-02
#   Significant difference in medians.
#   Mann-Whitney U test stats: 115496.0, p-value: 3.74e-02
#   Significant difference in medians.
# Source is: Self_Pay Target is: Government 0 2
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1874
#   Mann-Whitney U test stats: 132099.0, p-value: 1.20e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 127792.0, p-value: 5.41e-01
#   No significant difference in medians.
# Source is: Self_Pay Target is: Medicare 0 3
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1842
#   Mann-Whitney U test stats: 117363.0, p-value: 9.45e-02
#   No significant difference in medians.
#   Mann-Whitney U test stats: 129064.0, p-value: 3.74e-01
#   No significant difference in medians.
# Source is: Self_Pay Target is: Medicaid 0 4
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 609 source_count is: 500
# number of codes is: 1908
#   Mann-Whitney U test stats: 131131.0, p-value: 1.79e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 118347.0, p-value: 1.45e-01
#   No significant difference in medians.
# Source is: Private Target is: Self_Pay 1 0
# number of target indices is: 609 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1858
#   Mann-Whitney U test stats: 119184.0, p-value: 2.03e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 138615.0, p-value: 2.87e-03
#   Significant difference in medians.
# Source is: Private Target is: Government 1 2
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1816
#   Mann-Whitney U test stats: 128218.0, p-value: 4.81e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 123183.0, p-value: 6.91e-01
#   No significant difference in medians.
# Source is: Private Target is: Medicare 1 3
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1759
#   Mann-Whitney U test stats: 117823.0, p-value: 1.16e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 128805.0, p-value: 4.05e-01
#   No significant difference in medians.
# Source is: Private Target is: Medicaid 1 4
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 22548 source_count is: 500
# number of codes is: 1950
#   Mann-Whitney U test stats: 123104.0, p-value: 6.78e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 125453.0, p-value: 9.21e-01
#   No significant difference in medians.
# Source is: Government Target is: Self_Pay 2 0
# number of target indices is: 609 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1861
#   Mann-Whitney U test stats: 120967.0, p-value: 3.77e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 118485.0, p-value: 1.54e-01
#   No significant difference in medians.
# Source is: Government Target is: Private 2 1
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1880
#   Mann-Whitney U test stats: 126932.0, p-value: 6.72e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 120175.0, p-value: 2.91e-01
#   No significant difference in medians.
# Source is: Government Target is: Medicare 2 3
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1942
#   Mann-Whitney U test stats: 112287.0, p-value: 5.37e-03
#   Significant difference in medians.
#   Mann-Whitney U test stats: 127152.0, p-value: 6.38e-01
#   No significant difference in medians.
# Source is: Government Target is: Medicaid 2 4
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 1781 source_count is: 500
# number of codes is: 1961
#   Mann-Whitney U test stats: 123966.0, p-value: 8.21e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 121307.0, p-value: 4.19e-01
#   No significant difference in medians.
# Source is: Medicare Target is: Self_Pay 3 0
# number of target indices is: 609 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1864
#   Mann-Whitney U test stats: 123170.0, p-value: 6.89e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 119125.0, p-value: 1.98e-01
#   No significant difference in medians.
# Source is: Medicare Target is: Private 3 1
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1787
#   Mann-Whitney U test stats: 125820.0, p-value: 8.58e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 118645.0, p-value: 1.64e-01
#   No significant difference in medians.
# Source is: Medicare Target is: Government 3 2
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1841
#   Mann-Whitney U test stats: 129855.0, p-value: 2.88e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 125474.0, p-value: 9.17e-01
#   No significant difference in medians.
# Source is: Medicare Target is: Medicaid 3 4
# number of target indices is: 5783 target_count is: 500
# number of source indices is: 28208 source_count is: 500
# number of codes is: 1913
#   Mann-Whitney U test stats: 126316.0, p-value: 7.73e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 122964.0, p-value: 6.56e-01
#   No significant difference in medians.
# Source is: Medicaid Target is: Self_Pay 4 0
# number of target indices is: 609 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 1899
#   Mann-Whitney U test stats: 118356.0, p-value: 1.46e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 114977.0, p-value: 2.82e-02
#   Significant difference in medians.
# Source is: Medicaid Target is: Private 4 1
# number of target indices is: 22548 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 1900
#   Mann-Whitney U test stats: 133690.0, p-value: 5.71e-02
#   No significant difference in medians.
#   Mann-Whitney U test stats: 121912.0, p-value: 4.99e-01
#   No significant difference in medians.
# Source is: Medicaid Target is: Government 4 2
# number of target indices is: 1781 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 2017
#   Mann-Whitney U test stats: 120364.0, p-value: 3.10e-01
#   No significant difference in medians.
#   Mann-Whitney U test stats: 125912.0, p-value: 8.42e-01
#   No significant difference in medians.
# Source is: Medicaid Target is: Medicare 4 3
# number of target indices is: 28208 target_count is: 500
# number of source indices is: 5783 source_count is: 500
# number of codes is: 1820
#   Mann-Whitney U test stats: 114303.0, p-value: 1.92e-02
#   Significant difference in medians.
#   Mann-Whitney U test stats: 129771.0, p-value: 2.96e-01
#   No significant difference in medians.
